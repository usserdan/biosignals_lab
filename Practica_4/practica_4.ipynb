# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
# import pandas as pd

# %%
# Se cargan los datos de la señal EKG desde el archivo
data = sio.loadmat('data/EKG_data2.mat')

print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'EKG'])

# %%
# Señal EKG del diccionario de datos
ekg_signal = data['EKG'][0]

# Se visualiza
plt.figure(figsize=(10, 4))
plt.plot(ekg_signal)
plt.title('Señal EKG')
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()

# %% [markdown]
# Se puede recortar un poco mas la senal de manera que visualice mejor la dinamica

# %%
# Recortar la señal EKG hasta 500 muestras
ekg_signal_recortada = ekg_signal[:500]

# Visualizar la señal recortada
plt.figure(figsize=(10, 4))
plt.plot(ekg_signal_recortada)
plt.title('Señal EKG Recortada')
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()

# %% [markdown]
# Mismo proceso para la senal EMG

# %%
# Se cargan los datos de la señal EMG desde el archivo
data_EMG = sio.loadmat('data/EMG_data2.mat')

print(data_EMG.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'EMG'])

# %%
signal_EMG = data_EMG['EMG'][0]

# Se visualiza
plt.figure(figsize=(10, 4))
plt.plot(signal_EMG)
plt.title('Señal EMG')
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()

# %%
# Desde la muestra 200 hasta la 800
emg_signal_recortada = signal_EMG[200:800]

# Visualizar la señal recortada
plt.figure(figsize=(10, 4))
plt.plot(emg_signal_recortada)
plt.title('Señal EMG Recortada')
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.grid(True)
plt.show()
